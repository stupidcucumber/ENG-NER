# %%
from src.features import sentence2features

# %%
sentence2features("I love this beach, it just is a very nice place!")
# Out:
# [{'token.lower()': 'i',
#   'token[-3:]': 'I',
#   'token[-2:]': 'I',
#   'token[:3]': 'I',
#   'token[:2]': 'I',
#   'token.isupper()': True,
#   'token.istitle()': True,
#   'token.isdigit()': False,
#   'contains_digit': False,
#   'bias': 1.0,
#   '1:token.lower()': 'love',
#   '1:token[-3:]': 'ove',
#   '1:token[-2:]': 've',
#   '1:token[:3]': 'lov',
#   '1:token[:2]': 'lo',
#   '1:token.isupper()': False,
#   '1:token.istitle()': False,
#   '1:token.isdigit()': False,
#   '1:contains_digit': False,
#   'BOS': True,
#   'EOS': False},
#  {'0:token.lower()': 'i',
#   '0:token[-3:]': 'I',
#   '0:token[-2:]': 'I',
#   '0:token[:3]': 'I',
#   '0:token[:2]': 'I',
#   '0:token.isupper()': True,
#   '0:token.istitle()': True,
#   '0:token.isdigit()': False,
#   '0:contains_digit': False,
#   'token.lower()': 'love',
#   'token[-3:]': 'ove',
#   'token[-2:]': 've',
#   'token[:3]': 'lov',
#   'token[:2]': 'lo',
#   'token.isupper()': False,
#   'token.istitle()': False,
# ...
